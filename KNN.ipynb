# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from IPython import display

# %% [markdown]
# > It will first calculate the distance between the data points
#
# > find the K nearest data points
#
# > The majority of votes will be the prediction

# %%
display.Image("photo_2021-01-04_10-50-58.jpg",width=700, height=900)

# %%
X, y = make_moons(noise = 0.3, random_state = 10)

data = pd.DataFrame(X, columns=["X1", "X2"])
data['y'] = y

plt.figure(figsize=(10,6))
plt.title('Plot 1')
sns.scatterplot(data=data, x= "X1", y= "X2", hue="y", style="y", s=200)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

model = KNeighborsClassifier(n_neighbors = 5)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
xx1, xx2 = np.meshgrid(np.arange(-1.6, 2.5, 0.005), np.arange(-1.1, 1.55, 0.005))
XX = np.vstack((xx1.ravel(), xx2.ravel())).T

yy = model.predict(XX)

plt.figure(figsize=(10,6))
sns.scatterplot(x=XX[:,0], y=XX[:,1], hue=yy, palette = "gist_gray",  alpha = 0.3,sizes=[3,3],legend=False)
sns.scatterplot(x=data['X1'], y=data['X2'], hue = data['y'],  s = 100)
plt.title('KNN Decision Boundary (K = 5)')
plt.show()

# %%
print("When K is 5, the accuracy",accuracy_score(y_pred, y_test))
# Out:
# When K is 5, the accuracy 0.9666666666666667

# %%
model = KNeighborsClassifier(n_neighbors = 3)

model.fit(X_train, y_train)

yy = model.predict(XX)

plt.figure(figsize=(10,6))
sns.scatterplot(x=XX[:,0], y=XX[:,1], hue=yy, palette = "gist_gray",  alpha = 0.3,sizes=[3,3],legend=False)
sns.scatterplot(x=data['X1'], y=data['X2'], hue = data['y'],  s = 100)
plt.title('KNN Decision Boundary (K = 3)')
plt.show()

# %%
print("When K is 3, the accuracy",accuracy_score(y_pred, y_test))
# Out:
# When K is 3, the accuracy 0.9666666666666667

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris

data = load_iris()

n_clusters = 3

model = KMeans(n_clusters = n_clusters)

model.fit(data.data[:,:2])


xx1, xx2 = np.meshgrid( np.arange(4.25, 8, 0.01), np.arange(1.9, 4.5, 0.01))

XX = np.vstack((xx1.ravel(), xx2.ravel())).T

XX
# Out:
# array([[4.25, 1.9 ],
#        [4.26, 1.9 ],
#        [4.27, 1.9 ],
#        ...,
#        [7.97, 4.49],
#        [7.98, 4.49],
#        [7.99, 4.49]])

# %%
yy = model.predict(XX)

plt.figure(figsize=(10,6))
sns.scatterplot(x=XX[:,0], y=XX[:,1], hue=yy, palette = "gist_gray",  alpha = 0.3,sizes=[3,3],legend=False)
sns.scatterplot(x=data.data[:,0], y=data.data[:,1], hue = data.target,  s = 100)
plt.title('KMeans Decision Boundary (K = 3)')
plt.show()
